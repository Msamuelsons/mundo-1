# %%
from sklearn.datasets import make_regression
import matplotlib.pyplot as plt

# %%
x, y = make_regression(n_samples=200, n_features=1, noise=30) # n_samples = quantidade de dados, n_features = quantidade de caracteristicas, noise = quantidade de ruido
plt.scatter(x, y)
plt.show()

# %%
from sklearn.linear_model import LinearRegression
modelo = LinearRegression()

# %% [markdown]
# > O fit intercept calcula o coeficiente linear da equação da reta

# %%
modelo.fit(x, y)
# Out:
# LinearRegression()

# %%
# Para ver o valor do coeficiente angular (inclinação da reta)
print("Coeficiente angular:", modelo.coef_[0])

# Para ver o intercepto (coeficiente linear)
print("Intercepto:", modelo.intercept_)
# Out:
# Coeficiente angular: 83.66177806117881
# Intercepto: 2.3901438122526737

# %%
import numpy as np
plt.scatter(x, y)
xreg = np.linspace(-3, 3, 100)
plt.plot(xreg, xreg * modelo.coef_[0] + modelo.intercept_, color='red')
plt.show()
